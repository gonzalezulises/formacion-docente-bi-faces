# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-02-data-wrangling/laboratorios/entregable_dataset_limpio.ipynb)

# %% [markdown]
# # Entregable — Dataset limpio y documentado
#
# **Módulo 2: Data Wrangling accesible (Python + SQL)**
# **Instructor:** Gabriel Gómez
#
# ---
#
# ## Instrucciones
#
# Este notebook es la plantilla para tu entregable del Módulo 2. Debes:
#
# 1. Elegir un dataset del repositorio (o uno propio relacionado con tu contexto en FACES)
# 2. Aplicar las técnicas de wrangling aprendidas
# 3. Completar cada sección con tu análisis y código
# 4. El resultado debe ser un dataset limpio, documentado y listo para análisis
#
# **Criterios de evaluación:**
# - Limpieza apropiada (faltantes, outliers, tipos)
# - Justificación de cada decisión
# - Diccionario de variables completo
# - Reproducibilidad del proceso

# %% [markdown]
# ---
#
# ## 1. Contexto
#
# *Describe brevemente qué problema o pregunta quieres responder con estos datos. ¿Para qué serviría este dataset limpio?*

# %% [markdown]
# **Tu respuesta aquí:**
#
# (Ejemplo: "Quiero analizar los factores que influyen en el rendimiento académico de estudiantes de Administración para identificar posibles acciones de retención.")

# %% [markdown]
# ---
#
# ## 2. Fuente de datos
#
# *Indica de dónde provienen los datos, cuándo fueron recolectados y cualquier limitación conocida.*

# %% [markdown]
# **Tu respuesta aquí:**
#
# - **Archivo:**
# - **Fuente original:**
# - **Periodo:**
# - **Limitaciones conocidas:**

# %%
import pandas as pd
import numpy as np

# Carga tu dataset aquí
# df = pd.read_csv('../datasets/universidad/rendimiento_academico.csv')
# df.head()

# %%
# Inspección inicial
# df.info()

# %%
# Estadísticas descriptivas
# df.describe()

# %% [markdown]
# ---
#
# ## 3. Proceso de limpieza
#
# *Documenta cada paso de limpieza que apliques. Para cada transformación, explica POR QUÉ la hiciste.*

# %% [markdown]
# ### 3.1 Corrección de tipos de datos
#
# *¿Hay columnas con tipos incorrectos? (ej: fechas como texto, códigos numéricos que deberían ser texto)*

# %%
# Tu código de corrección de tipos aquí

# %% [markdown]
# ### 3.2 Tratamiento de datos faltantes
#
# *Para cada columna con faltantes, indica: cuántos hay, por qué faltan (si lo sabes), y qué decisión tomaste (eliminar, imputar, dejar).*

# %%
# Diagnóstico de faltantes

# %%
# Tratamiento de faltantes

# %% [markdown]
# ### 3.3 Detección y manejo de outliers
#
# *¿Qué valores atípicos encontraste? ¿Son errores o valores legítimos?*

# %%
# Detección de outliers

# %%
# Tratamiento de outliers

# %% [markdown]
# ### 3.4 Variables derivadas
#
# *¿Qué nuevas variables creaste y por qué son útiles para el análisis?*

# %%
# Creación de variables derivadas

# %% [markdown]
# ---
#
# ## 4. Diccionario de variables
#
# *Completa la tabla con TODAS las variables del dataset final (originales y derivadas).*
#
# | Variable | Tipo | Descripción | Rango/Valores posibles | Notas |
# |----------|------|-------------|----------------------|-------|
# | ejemplo_id | int | Identificador único | 1-999 | Sin faltantes |
# | ... | ... | ... | ... | ... |

# %% [markdown]
# ---
#
# ## 5. Dataset resultante
#
# *Muestra las primeras filas del dataset limpio y sus estadísticas finales.*

# %%
# Dataset limpio: primeras filas
# df_limpio.head(10)

# %%
# Dataset limpio: info final
# df_limpio.info()

# %%
# Dataset limpio: estadísticas
# df_limpio.describe()

# %%
# Exportar dataset limpio
# df_limpio.to_csv('dataset_limpio.csv', index=False)
# print(f"Dataset exportado: {len(df_limpio)} filas, {len(df_limpio.columns)} columnas")

# %% [markdown]
# ---
#
# ## 6. Notas para reproducibilidad
#
# *Incluye toda la información necesaria para que otra persona pueda reproducir tu proceso de limpieza.*

# %% [markdown]
# **Tu respuesta aquí:**
#
# - **Entorno:** Google Colab / Jupyter (versión de Python: )
# - **Librerías utilizadas:** pandas, numpy
# - **Orden de ejecución:** Las celdas deben ejecutarse en orden secuencial
# - **Decisiones clave:**
#   1. ...
#   2. ...
#   3. ...
# - **Limitaciones del dataset limpio:**
#   1. ...
#   2. ...
