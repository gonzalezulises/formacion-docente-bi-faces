# %% [markdown]
# # 🧪 Laboratorio 2: Exploración con Pandas
#
# **Módulo 01** | **Laboratorio 2** | **Duración estimada: 1h 30min**
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-01-fundamentos/laboratorios/lab_02_pandas_ejercicios.ipynb)

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Descripción | Nivel |
# |---|-------------|-------------|-------|
# | 1 | Carga de datos | Cargar archivos CSV con Pandas y verificar su estructura | Aplicación |
# | 2 | Exploración | Usar funciones de exploración para entender los datos | Aplicación |
# | 3 | Filtrado | Aplicar filtros simples y compuestos sobre DataFrames | Aplicación |
# | 4 | Agrupación | Usar groupby para obtener resúmenes estadísticos | Análisis |
# | 5 | Transformación | Crear nuevas columnas calculadas a partir de datos existentes | Síntesis |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# En este laboratorio trabajarás con datos reales de FACES-UC: matrícula estudiantil y rendimiento académico. Estas son exactamente las tablas que se manejan en los departamentos y direcciones de escuela. Al dominar estas operaciones con Pandas, podrás responder preguntas como:
#
# - ¿Cuántos estudiantes activos tiene cada carrera?
# - ¿Cuál es el promedio académico por carrera y género?
# - ¿Qué semestre tiene el mejor rendimiento?
# - ¿Qué porcentaje de materias aprueban los estudiantes?
#
# Todo esto en **segundos**, sin abrir Excel.

# %% [markdown]
# ---
#
# ## 📦 Configuración Inicial
#
# Ejecuta esta celda antes de comenzar los ejercicios.

# %%
import pandas as pd

# Configurar Pandas para mostrar más filas y columnas
pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 20)
pd.set_option('display.width', 120)

print(f"Pandas versión: {pd.__version__}")
print("Configuración lista")

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Cargar y explorar el dataset de matrícula
#
# 1. Carga el archivo `../../datasets/universidad/matricula_faces.csv` en un DataFrame llamado `matricula`
# 2. Muestra las primeras 10 filas con `.head(10)`
# 3. Muestra las dimensiones del DataFrame (filas y columnas)
# 4. Muestra los tipos de datos de cada columna con `.dtypes`
# 5. Muestra el resumen con `.info()`

# %%
# Ejercicio 1: Cargar y explorar matricula_faces.csv
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: Valores únicos
#
# Usando el DataFrame `matricula`, responde:
#
# 1. ¿Cuántas carreras únicas hay? ¿Cuáles son?
# 2. ¿Cuántos períodos académicos cubre el dataset? ¿Cuál es el primero y el último?
# 3. ¿Cuántas sedes hay? ¿Cuáles son?
# 4. ¿Cuántos tipos de ingreso existen? ¿Cuáles son?

# %%
# Ejercicio 2: Valores únicos
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Filtrado - Estudiantes de Administración activos
#
# 1. Filtra el DataFrame para obtener solo los estudiantes de la carrera "Administracion" que tengan estatus "Activo"
# 2. ¿Cuántos registros cumplen esta condición?
# 3. De estos estudiantes filtrados, ¿cuál es la distribución por género?
# 4. ¿Cuál es la distribución por sede?
# 5. ¿Cuál es la edad promedio de estos estudiantes?

# %%
# Ejercicio 3: Filtrar Administración activos
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: GroupBy - Estudiantes por sede y estatus
#
# 1. Agrupa el DataFrame `matricula` por `sede` y `estatus`, y cuenta el número de estudiantes en cada combinación
# 2. ¿Cuál sede tiene más estudiantes activos?
# 3. ¿Cuál sede tiene mayor tasa de retiro (proporción de retirados respecto al total de esa sede)?
# 4. Crea una tabla cruzada (`pd.crosstab`) de sede por estatus

# %%
# Ejercicio 4: GroupBy por sede y estatus
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Cargar y explorar rendimiento académico
#
# 1. Carga el archivo `../../datasets/universidad/rendimiento_academico.csv` en un DataFrame llamado `rendimiento`
# 2. Muestra las primeras filas y la estructura del DataFrame
# 3. Calcula el promedio de la columna `promedio` agrupado por `carrera`
# 4. ¿Qué carrera tiene el promedio más alto? ¿Y el más bajo?

# %%
# Ejercicio 5: Rendimiento académico - promedio por carrera
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Filtrado avanzado - Estudiantes destacados
#
# Usando el DataFrame `rendimiento`:
#
# 1. Filtra los estudiantes con `promedio >= 15` (distinguidos o sobresalientes)
# 2. ¿Cuántos hay en total?
# 3. ¿Cómo se distribuyen por género?
# 4. ¿Cómo se distribuyen por carrera?
# 5. ¿Qué porcentaje de los estudiantes destacados tiene beca?

# %%
# Ejercicio 6: Estudiantes con promedio >= 15
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 7: Promedio por semestre
#
# Usando el DataFrame `rendimiento`:
#
# 1. Agrupa por `semestre` y calcula el promedio de la columna `promedio`
# 2. ¿Qué semestre tiene el promedio más alto?
# 3. ¿Qué semestre tiene el promedio más bajo?
# 4. Calcula también la cantidad de estudiantes y la asistencia promedio por semestre
# 5. ¿Hay alguna relación entre el semestre y el rendimiento? (observa si el promedio sube o baja a medida que avanzan los semestres)

# %%
# Ejercicio 7: Promedio por semestre
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 8: Crear una nueva columna calculada
#
# Usando el DataFrame `rendimiento`:
#
# 1. Crea una nueva columna llamada `tasa_aprobacion` que calcule:
#    $$\text{tasa\_aprobacion} = \frac{\text{materias\_aprobadas}}{\text{materias\_inscritas}}$$
#
# 2. Muestra las primeras 10 filas con la nueva columna
# 3. ¿Cuál es la tasa de aprobación promedio general?
# 4. ¿Cuál es la tasa de aprobación promedio por carrera?
# 5. Filtra los estudiantes con tasa de aprobación de 1.0 (aprobaron todo). ¿Cuántos son? ¿Cuál es su promedio?

# %%
# Ejercicio 8: Columna tasa_aprobacion
# Tu código aquí

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste las operaciones fundamentales de Pandas con datos reales de FACES:
#
# | Ejercicio | Operación Pandas | Pregunta de negocio |
# |-----------|-----------------|---------------------|
# | 1 | `read_csv`, `head`, `info` | ¿Cómo se estructuran nuestros datos de matrícula? |
# | 2 | `unique`, `nunique` | ¿Qué carreras, períodos y sedes tenemos? |
# | 3 | Filtrado con `&` | ¿Cómo son los estudiantes activos de Administración? |
# | 4 | `groupby`, `crosstab` | ¿Cómo se distribuyen por sede y estatus? |
# | 5 | `groupby().mean()` | ¿Cuál carrera tiene mejor rendimiento? |
# | 6 | Filtrado + `value_counts` | ¿Quiénes son los estudiantes destacados? |
# | 7 | `groupby().agg()` | ¿Cómo varía el rendimiento por semestre? |
# | 8 | Columnas calculadas | ¿Cuál es la tasa de aprobación real? |
#
# ## 📚 Referencias
#
# 1. McKinney, W. (2022). *Python for Data Analysis* (3rd ed.). O'Reilly Media.
#
# 2. Pandas Development Team. (2024). *Pandas Documentation*. https://pandas.pydata.org/docs/
#
# 3. VanderPlas, J. (2016). *Python Data Science Handbook*. O'Reilly Media.
