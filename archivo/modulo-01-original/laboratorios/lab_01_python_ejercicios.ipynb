# %% [markdown]
# # 🧪 Laboratorio 1: Ejercicios de Python
#
# **Módulo 01** | **Laboratorio 1** | **Duración estimada: 1h 30min**
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-01-fundamentos/laboratorios/lab_01_python_ejercicios.ipynb)

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Descripción | Nivel |
# |---|-------------|-------------|-------|
# | 1 | Variables y tipos | Practicar la creación y uso de variables de diferentes tipos | Aplicación |
# | 2 | Strings | Manipular cadenas de texto con métodos de Python | Aplicación |
# | 3 | Listas y diccionarios | Crear, acceder y modificar estructuras de datos | Aplicación |
# | 4 | Control de flujo | Resolver problemas usando condicionales y bucles | Aplicación |
# | 5 | Funciones | Crear funciones reutilizables para cálculos académicos | Síntesis |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# Este laboratorio te permite practicar los fundamentos de Python con ejercicios directamente relacionados con tu trabajo diario: gestionar información de presupuesto, formatear datos de profesores, organizar catálogos de materias y analizar calificaciones. Cada ejercicio simula una tarea real que podrías automatizar en tu departamento.

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Variables de presupuesto departamental
#
# Crea variables para representar el presupuesto de un departamento de FACES:
#
# 1. `nombre_departamento` (str): El nombre del departamento (ej: "Economía")
# 2. `presupuesto_anual` (int): El presupuesto anual en bolívares (ej: 500000)
# 3. `porcentaje_ejecutado` (float): El porcentaje ejecutado hasta la fecha (ej: 67.5)
# 4. `tiene_deficit` (bool): Si el departamento tiene déficit o no
# 5. `anio_fiscal` (int): El año fiscal actual
#
# Luego:
# - Calcula el monto ejecutado (`presupuesto_anual * porcentaje_ejecutado / 100`)
# - Calcula el monto disponible
# - Imprime un resumen formateado con f-strings
# - Verifica el tipo de cada variable con `type()`

# %%
# Ejercicio 1: Variables de presupuesto departamental
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: Operaciones con strings - Formatear nombres de profesores
#
# Tienes la siguiente lista de nombres de profesores escritos de forma inconsistente:
#
# ```python
# nombres = [
#     "  maria garcia LOPEZ ",
#     "CARLOS rodriguez",
#     "ana MENDEZ perez  ",
#     "  pedro jose RAMIREZ",
#     "LAURA martinez SILVA"
# ]
# ```
#
# Para cada nombre:
# 1. Elimina los espacios sobrantes al inicio y final (`.strip()`)
# 2. Convértelo a formato título (`.title()`)
# 3. Agrega el prefijo "Prof." al inicio
# 4. Imprime el resultado
# 5. Al final, indica cuál es el nombre más largo (mayor `len()`)

# %%
# Ejercicio 2: Formatear nombres de profesores
nombres = [
    "  maria garcia LOPEZ ",
    "CARLOS rodriguez",
    "ana MENDEZ perez  ",
    "  pedro jose RAMIREZ",
    "LAURA martinez SILVA"
]

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Listas - Gestionar códigos de materias
#
# Tienes la siguiente lista de códigos de materias:
#
# ```python
# materias = ["ECO-101", "ADM-201", "CON-301", "EST-101", "MAT-201"]
# ```
#
# Realiza las siguientes operaciones:
# 1. Imprime la cantidad de materias
# 2. Agrega "ING-101" y "SOC-201" a la lista
# 3. Elimina "MAT-201"
# 4. Ordena la lista alfabéticamente
# 5. Imprime la lista final
# 6. Usa un bucle para separar cada código en departamento y número (pista: usa `.split("-")`), e imprime el resultado en formato de tabla

# %%
# Ejercicio 3: Gestionar códigos de materias
materias = ["ECO-101", "ADM-201", "CON-301", "EST-101", "MAT-201"]

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: Diccionarios - Catálogo de materias
#
# Crea un diccionario llamado `catalogo` que represente un catálogo de materias. Cada clave es el código de la materia y cada valor es otro diccionario con: nombre, créditos, semestre, y tipo ("obligatoria" o "electiva").
#
# Incluye al menos 5 materias. Ejemplo:
#
# ```python
# catalogo = {
#     "ECO-101": {"nombre": "Introducción a la Economía", "creditos": 4, "semestre": 1, "tipo": "obligatoria"},
#     # ... más materias
# }
# ```
#
# Luego:
# 1. Imprime la información de una materia específica usando su código
# 2. Cuenta el total de créditos de todas las materias
# 3. Identifica cuántas materias son obligatorias y cuántas electivas
# 4. Imprime todas las materias formateadas como un catálogo

# %%
# Ejercicio 4: Catálogo de materias
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Condicionales - Clasificar ejecución presupuestaria
#
# Escribe un programa que clasifique el porcentaje de ejecución presupuestaria de un departamento:
#
# | Porcentaje ejecutado | Clasificación | Acción recomendada |
# |---------------------|--------------|--------------------|
# | >= 90% | Ejecución óptima | Mantener el ritmo |
# | 70% - 89% | Ejecución aceptable | Acelerar procesos pendientes |
# | 50% - 69% | Ejecución media | Revisar plan de gasto |
# | 30% - 49% | Ejecución baja | Alerta: riesgo de subejercicio |
# | < 30% | Ejecución crítica | Reunión urgente con dirección |
#
# Prueba tu código con estos valores: `92`, `75`, `55`, `35`, `18`

# %%
# Ejercicio 5: Clasificar ejecución presupuestaria
porcentajes = [92, 75, 55, 35, 18]

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Bucle for - Procesar calificaciones
#
# Dada la siguiente lista de calificaciones de una sección de Estadística I (escala 0-20):
#
# ```python
# calificaciones = [15, 8, 12, 19, 10, 7, 14, 16, 11, 6, 18, 13, 9, 17, 12, 10, 14, 8, 15, 11]
# ```
#
# Usa un bucle `for` para:
# 1. Calcular el promedio de la sección
# 2. Contar cuántos aprobaron (>= 10) y cuántos reprobaron
# 3. Encontrar la nota máxima y la mínima (sin usar `max()` ni `min()`)
# 4. Clasificar cada nota como Sobresaliente/Distinguido/Bueno/Regular/Reprobado y contar cuántos hay en cada categoría
# 5. Imprimir un informe completo con todos los resultados

# %%
# Ejercicio 6: Procesar calificaciones
calificaciones = [15, 8, 12, 19, 10, 7, 14, 16, 11, 6, 18, 13, 9, 17, 12, 10, 14, 8, 15, 11]

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 7: Funciones - Calcular índice académico
#
# Crea una función llamada `calcular_indice_academico` que reciba:
# - Una lista de notas (escala 0-20)
# - Una lista de créditos correspondientes a cada materia
#
# La función debe calcular el **índice académico ponderado**:
#
# $$\text{Índice} = \frac{\sum (nota_i \times cr\acute{e}ditos_i)}{\sum cr\acute{e}ditos_i}$$
#
# La función debe devolver un diccionario con:
# - `indice`: el índice académico ponderado (redondeado a 2 decimales)
# - `total_creditos`: el total de créditos
# - `materias_aprobadas`: cuántas materias tienen nota >= 10
# - `clasificacion`: "Cum Laude" (>= 18), "Magna" (>= 16), "Distinguido" (>= 14), "Regular" (< 14)
#
# Prueba con:
# ```python
# notas = [16, 14, 18, 12, 15]
# creditos = [4, 3, 4, 3, 2]
# ```

# %%
# Ejercicio 7: Función calcular_indice_academico
# Tu código aquí


# Probar la función
notas = [16, 14, 18, 12, 15]
creditos = [4, 3, 4, 3, 2]

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 8: Integración - Procesar estudiantes en riesgo
#
# Dada la siguiente lista de estudiantes (diccionarios), escribe un programa que:
#
# ```python
# estudiantes = [
#     {"nombre": "Ana Pérez", "carrera": "Economía", "promedio": 15.2, "asistencia": 92, "materias_reprobadas": 0},
#     {"nombre": "Carlos Gómez", "carrera": "Administración", "promedio": 9.5, "asistencia": 60, "materias_reprobadas": 4},
#     {"nombre": "Laura Torres", "carrera": "Contaduría", "promedio": 11.0, "asistencia": 78, "materias_reprobadas": 2},
#     {"nombre": "Miguel López", "carrera": "Economía", "promedio": 7.8, "asistencia": 45, "materias_reprobadas": 5},
#     {"nombre": "Sofía Herrera", "carrera": "RRII", "promedio": 17.5, "asistencia": 95, "materias_reprobadas": 0},
#     {"nombre": "Pedro Castillo", "carrera": "Administración", "promedio": 12.3, "asistencia": 82, "materias_reprobadas": 1},
#     {"nombre": "María Rivas", "carrera": "Contaduría", "promedio": 8.2, "asistencia": 55, "materias_reprobadas": 3},
#     {"nombre": "José Navarro", "carrera": "Economía", "promedio": 14.1, "asistencia": 88, "materias_reprobadas": 1},
# ]
# ```
#
# 1. Crea una función `evaluar_riesgo(estudiante)` que clasifique:
#    - **"ALTO"**: promedio < 10 O asistencia < 60% O materias_reprobadas >= 4
#    - **"MEDIO"**: promedio entre 10-12 O asistencia entre 60-75% O materias_reprobadas 2-3
#    - **"BAJO"**: los demás casos
#
# 2. Aplica la función a todos los estudiantes
# 3. Imprime un informe con:
#    - La lista completa clasificada
#    - Cuántos hay en cada nivel de riesgo
#    - Promedio general de la cohorte
#    - Los nombres de los estudiantes en riesgo ALTO (para seguimiento)

# %%
# Ejercicio 8: Procesar estudiantes en riesgo
estudiantes = [
    {"nombre": "Ana Pérez", "carrera": "Economía", "promedio": 15.2, "asistencia": 92, "materias_reprobadas": 0},
    {"nombre": "Carlos Gómez", "carrera": "Administración", "promedio": 9.5, "asistencia": 60, "materias_reprobadas": 4},
    {"nombre": "Laura Torres", "carrera": "Contaduría", "promedio": 11.0, "asistencia": 78, "materias_reprobadas": 2},
    {"nombre": "Miguel López", "carrera": "Economía", "promedio": 7.8, "asistencia": 45, "materias_reprobadas": 5},
    {"nombre": "Sofía Herrera", "carrera": "RRII", "promedio": 17.5, "asistencia": 95, "materias_reprobadas": 0},
    {"nombre": "Pedro Castillo", "carrera": "Administración", "promedio": 12.3, "asistencia": 82, "materias_reprobadas": 1},
    {"nombre": "María Rivas", "carrera": "Contaduría", "promedio": 8.2, "asistencia": 55, "materias_reprobadas": 3},
    {"nombre": "José Navarro", "carrera": "Economía", "promedio": 14.1, "asistencia": 88, "materias_reprobadas": 1},
]

# Tu código aquí

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste los fundamentos de Python aplicados al contexto universitario:
#
# | Ejercicio | Concepto principal | Contexto FACES |
# |-----------|-------------------|----------------|
# | 1 | Variables y tipos | Presupuesto departamental |
# | 2 | Strings | Formateo de nombres de profesores |
# | 3 | Listas | Códigos de materias |
# | 4 | Diccionarios | Catálogo académico |
# | 5 | Condicionales | Ejecución presupuestaria |
# | 6 | Bucles | Procesamiento de calificaciones |
# | 7 | Funciones | Índice académico ponderado |
# | 8 | Integración | Detección de estudiantes en riesgo |
#
# ## 📚 Referencias
#
# 1. Van Rossum, G. (2024). *The Python Tutorial*. Python Software Foundation. https://docs.python.org/3/tutorial/
#
# 2. Downey, A. B. (2015). *Think Python: How to Think Like a Computer Scientist* (2nd ed.). O'Reilly Media.
#
# 3. Sweigart, A. (2019). *Automate the Boring Stuff with Python* (2nd ed.). No Starch Press.
