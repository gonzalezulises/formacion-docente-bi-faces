# %% [markdown]
# # 🧪 Laboratorio 6: Modelo Predictivo sobre Rendimiento Académico
#
# **Módulo 03** | **Sesión 5** | **Duración estimada: 45min**
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-03-modelado-predictivo/laboratorios/lab_06_regresion_ejercicios.ipynb)

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Descripción | Nivel |
# |---|-------------|-------------|-------|
# | 1 | Pipeline completo | Construir un pipeline completo de regresión lineal de principio a fin | Aplicación |
# | 2 | Evaluación | Calcular e interpretar métricas de regresión (R², MAE, RMSE) | Análisis |
# | 3 | Visualización | Crear gráficos diagnósticos del modelo (predicho vs real) | Aplicación |
# | 4 | Experimentación | Experimentar con diferentes combinaciones de features | Análisis |
# | 5 | Interpretación | Interpretar coeficientes en el contexto universitario | Evaluación |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# En este laboratorio construirás **de principio a fin** un modelo predictivo que podría usarse en la vida real: predecir el promedio de un estudiante a partir de sus características. Este es el tipo de modelo que un coordinador de carrera podría usar para identificar tempranamente a estudiantes que necesitan apoyo.
#
# Al completar los 6 ejercicios, habrás practicado todo el flujo de trabajo de un proyecto de ciencia de datos aplicado a educación.

# %%
# Librerías necesarias — ejecuta esta celda primero
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
sns.set_style('whitegrid')

print('Librerías cargadas correctamente ✓')

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Cargar datos y seleccionar variables
#
# Carga el dataset `rendimiento_academico.csv` y prepara las variables:
#
# 1. Carga el CSV en un DataFrame llamado `df`
# 2. Convierte las columnas `beca` y `trabaja` de booleano a numérico (0/1)
# 3. Define la variable objetivo `y` = `promedio`
# 4. Define las features `X` con las columnas: `semestre`, `edad`, `asistencia_pct`, `materias_inscritas`, `beca_num`, `trabaja_num`
# 5. Muestra las primeras 5 filas de `X` y la distribución de `y` con `.describe()`

# %%
# Ejercicio 1: Cargar datos y seleccionar variables
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: División Train/Test
#
# Divide los datos en entrenamiento y prueba:
#
# 1. Usa `train_test_split` con `test_size=0.2` y `random_state=42`
# 2. Imprime el número de registros en train y test
# 3. Verifica que la proporción sea aproximadamente 80/20

# %%
# Ejercicio 2: División Train/Test
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Entrenar y evaluar el modelo
#
# Entrena un modelo de regresión lineal y calcula las métricas:
#
# 1. Crea un objeto `LinearRegression()` y entrénalo con los datos de train
# 2. Genera predicciones sobre el conjunto de test
# 3. Calcula las siguientes métricas sobre test:
#    - R² (coeficiente de determinación)
#    - MAE (error absoluto medio)
#    - RMSE (raíz del error cuadrático medio)
# 4. Imprime los resultados con interpretación (ej: "El modelo explica el X% de la variación")

# %%
# Ejercicio 3: Entrenar y evaluar el modelo
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: Gráfico Predicho vs Real
#
# Crea un gráfico de dispersión de valores predichos vs valores reales:
#
# 1. En el eje X: valores reales (`y_test`)
# 2. En el eje Y: valores predichos (`y_pred`)
# 3. Agrega la línea diagonal roja punteada (predicción perfecta)
# 4. Agrega título, etiquetas de ejes y leyenda
# 5. Comenta: ¿los puntos están cerca de la diagonal?

# %%
# Ejercicio 4: Gráfico Predicho vs Real
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Experimentar con features
#
# Prueba diferentes combinaciones de features y compara los R²:
#
# 1. **Modelo A**: solo `asistencia_pct` (regresión simple)
# 2. **Modelo B**: `asistencia_pct` + `materias_inscritas`
# 3. **Modelo C**: todas las features (el modelo del Ejercicio 3)
#
# Para cada modelo:
# - Entrena con los mismos datos de train
# - Calcula R² en test
# - Crea una tabla comparativa
#
# ¿Agregar más features siempre mejora el modelo?

# %%
# Ejercicio 5: Experimentar con features
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Interpretar coeficientes
#
# Usando el modelo completo (todas las features):
#
# 1. Crea un DataFrame con las features y sus coeficientes
# 2. Ordénalos por magnitud (valor absoluto) de mayor a menor
# 3. Responde:
#    - ¿Cuál es la feature con el coeficiente más grande (en valor absoluto)?
#    - ¿Qué significa ese coeficiente en palabras sencillas?
#    - ¿El coeficiente de `trabaja_num` es positivo o negativo? ¿Tiene sentido desde tu experiencia como docente?

# %%
# Ejercicio 6: Interpretar coeficientes
# Tu código aquí

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste el flujo completo de un modelo de regresión:
#
# | Paso | Qué hiciste |
# |------|-------------|
# | 1. Preparación | Cargaste datos, seleccionaste y transformaste variables |
# | 2. División | Separaste train/test para evaluar honestamente |
# | 3. Entrenamiento | Ajustaste un modelo de regresión lineal |
# | 4. Evaluación | Calculaste R², MAE, RMSE |
# | 5. Visualización | Creaste el gráfico predicho vs real |
# | 6. Experimentación | Probaste diferentes combinaciones de features |
# | 7. Interpretación | Analizaste qué factores influyen más |
#
# ## 📚 Referencias
#
# 1. Scikit-learn developers. (2024). *LinearRegression*. https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# 2. James, G., Witten, D., Hastie, T., & Tibshirani, R. (2021). *An Introduction to Statistical Learning* (2nd ed.). Springer.
