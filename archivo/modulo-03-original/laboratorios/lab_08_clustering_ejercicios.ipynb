# %% [markdown]
# # 🧪 Laboratorio 8: Segmentación de Perfiles Docentes
#
# **Módulo 03** | **Sesión 6** | **Duración estimada: 45min**
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-03-modelado-predictivo/laboratorios/lab_08_clustering_ejercicios.ipynb)

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Descripción | Nivel |
# |---|-------------|-------------|-------|
# | 1 | Preparación de datos | Seleccionar, limpiar y estandarizar variables para clustering | Aplicación |
# | 2 | Selección de K | Aplicar el método del codo y silhouette para elegir K | Análisis |
# | 3 | K-Means | Ejecutar K-Means y analizar los clusters resultantes | Aplicación |
# | 4 | Perfilamiento | Construir una tabla de perfiles y nombrar cada cluster | Evaluación |
# | 5 | Comunicación | Traducir los hallazgos en recomendaciones de gestión de talento | Síntesis |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# La **segmentación** es una herramienta poderosa para la gestión del talento docente. En lugar de tratar a todos los docentes de FACES igual, este análisis permite identificar **perfiles diferenciados** y diseñar intervenciones específicas:
#
# - Docentes con alta carga y baja satisfacción necesitan alivio de carga
# - Docentes jóvenes y productivos necesitan mentoría y oportunidades de crecimiento
# - Docentes experimentados y satisfechos pueden servir como mentores
#
# Al completar este laboratorio, habrás construido un análisis que podrías presentar al Decanato de FACES.

# %%
# Librerías necesarias — ejecuta esta celda primero
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
sns.set_style('whitegrid')

print('Librerías cargadas correctamente ✓')

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Seleccionar features, verificar datos y estandarizar
#
# Prepara los datos para clustering:
#
# 1. Carga `encuesta_docente.csv` en un DataFrame
# 2. Selecciona las columnas numéricas relevantes para clustering:
#    `satisfaccion_general`, `satisfaccion_salarial`, `satisfaccion_infraestructura`, `satisfaccion_desarrollo`, `publicaciones`, `carga_horaria`, `antiguedad`
# 3. Verifica si hay datos faltantes (`.isnull().sum()`). Si los hay, elimina esas filas
# 4. Estandariza los datos con `StandardScaler`
# 5. Verifica que las variables estandarizadas tengan media cercana a 0 y desviación estándar cercana a 1

# %%
# Ejercicio 1: Seleccionar features, verificar datos y estandarizar
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: Método del Codo (Elbow Plot)
#
# Determina el número óptimo de clusters:
#
# 1. Ajusta K-Means para K = 2, 3, 4, 5, 6, 7, 8
# 2. Guarda la inercia (`.inertia_`) de cada modelo
# 3. Crea el gráfico del codo (K vs inercia)
# 4. Identifica visualmente dónde está el "codo" de la curva
# 5. Comenta: ¿cuántos clusters sugiere el método del codo?

# %%
# Ejercicio 2: Método del Codo
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Análisis de Silhouette
#
# Complementa el método del codo con el silhouette score:
#
# 1. Para cada K de 2 a 8, calcula el `silhouette_score` promedio
# 2. Imprime los valores en una tabla
# 3. Crea un gráfico de K vs silhouette score
# 4. ¿Cuál K maximiza el silhouette score?
# 5. ¿Coincide con lo que sugiere el método del codo?

# %%
# Ejercicio 3: Análisis de Silhouette
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: Ajustar K-Means y asignar etiquetas
#
# Con el K elegido en los ejercicios anteriores:
#
# 1. Ajusta K-Means con el K seleccionado (usa `random_state=42`, `n_init=10`)
# 2. Agrega la columna `cluster` al DataFrame original
# 3. Muestra cuántos docentes hay en cada cluster
# 4. Visualiza los clusters usando PCA para reducir a 2 dimensiones (scatter plot coloreado por cluster)

# %%
# Ejercicio 4: Ajustar K-Means y asignar etiquetas
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Tabla de perfiles
#
# Construye una tabla que muestre el perfil promedio de cada cluster:
#
# 1. Calcula la media de cada variable por cluster usando `.groupby('cluster').mean()`
# 2. Agrega el número de docentes por cluster
# 3. Redondea a 2 decimales
# 4. Muestra la tabla transpuesta (`.T`) para facilitar la lectura
# 5. ¿Qué cluster tiene la satisfacción más baja? ¿Y el que tiene más publicaciones?

# %%
# Ejercicio 5: Tabla de perfiles
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Nombrar clusters y escribir recomendación
#
# La parte más importante del análisis:
#
# 1. Basándote en la tabla de perfiles, asigna un **nombre descriptivo** a cada cluster
#    (ej: "Docentes experimentados y satisfechos", "Docentes sobrecargados", etc.)
# 2. Identifica el cluster que podría necesitar **intervención de RRHH** (el de mayor riesgo)
# 3. Escribe un párrafo breve (3-5 oraciones) describiendo:
#    - Las características de ese cluster
#    - Por qué representa un riesgo para la institución
#    - Qué acción concreta recomendarías al Decanato de FACES

# %%
# Ejercicio 6: Nombrar clusters y escribir recomendación
# Tu código aquí

# Nombres de los clusters:
# Cluster 0: 
# Cluster 1: 
# Cluster 2: 

# Cluster de mayor riesgo: 

# Recomendación para el Decanato:
#

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste:
#
# | Paso | Qué hiciste |
# |------|-------------|
# | 1. Preparación | Seleccionaste, limpiaste y estandarizaste datos |
# | 2. Método del codo | Identificaste el K óptimo visualmente |
# | 3. Silhouette | Confirmaste el K con una métrica cuantitativa |
# | 4. K-Means | Ajustaste el modelo y visualizaste clusters |
# | 5. Perfilamiento | Construiste una tabla de perfiles por cluster |
# | 6. Comunicación | Nombraste los clusters y escribiste una recomendación |
#
# ## 📚 Referencias
#
# 1. Scikit-learn developers. (2024). *KMeans*. https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
#
# 2. Jain, A. K. (2010). *Data clustering: 50 years beyond K-means*. Pattern Recognition Letters, 31(8), 651-666.
