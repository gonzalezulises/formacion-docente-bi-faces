# %% [markdown]
# # 🧪 Laboratorio 7: Clasificación con Datos Financieros
#
# **Módulo 03** | **Sesión 5** | **Duración estimada: 45min**
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-03-modelado-predictivo/laboratorios/lab_07_clasificacion_ejercicios.ipynb)

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Descripción | Nivel |
# |---|-------------|-------------|-------|
# | 1 | Ingeniería de features | Crear variables derivadas (ratios financieros) a partir de datos crudos | Aplicación |
# | 2 | Clasificación múltiple | Entrenar y comparar 3 modelos de clasificación diferentes | Análisis |
# | 3 | Evaluación comparativa | Comparar modelos usando métricas estándar de clasificación | Evaluación |
# | 4 | Selección de modelo | Elegir el mejor modelo y justificar la elección | Evaluación |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# En las carreras de Contaduría, Administración y Economía de FACES, el **análisis de estados financieros** es una competencia fundamental. En este laboratorio aplicarás técnicas de machine learning para clasificar empresas como "rentables" o "no rentables" — un problema real que enfrentan analistas financieros, auditores y asesores empresariales.
#
# Al comparar múltiples modelos, desarrollarás el criterio para elegir la herramienta adecuada según el contexto.

# %%
# Librerías necesarias — ejecuta esta celda primero
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report
)

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
sns.set_style('whitegrid')

print('Librerías cargadas correctamente ✓')

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Crear la variable objetivo
#
# Carga `estados_financieros.csv` y crea la variable objetivo:
#
# 1. Carga el CSV en un DataFrame llamado `fin`
# 2. Explora los datos: muestra las primeras filas y las columnas disponibles
# 3. Crea una nueva columna `rentable` que valga:
#    - `1` si `utilidad_neta_musd > 0` (la empresa es rentable)
#    - `0` si `utilidad_neta_musd <= 0` (la empresa no es rentable)
# 4. Muestra la distribución de la variable objetivo (cuántas empresas rentables vs no rentables)

# %%
# Ejercicio 1: Crear la variable objetivo
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: Calcular ratios financieros
#
# Crea las siguientes variables derivadas (ratios financieros) que servirán como features:
#
# 1. **ROA** (Return on Assets) = `utilidad_neta_musd / activos_musd`
#    - Qué tan eficientemente usa la empresa sus activos
# 2. **Endeudamiento** = `pasivos_musd / activos_musd`
#    - Proporción de la empresa que está financiada con deuda
# 3. **Margen neto** = `utilidad_neta_musd / ingresos_musd`
#    - Qué porcentaje de cada dólar de ingreso se convierte en ganancia
#
# **Importante:**
# - Elimina filas con valores infinitos o NaN después de calcular los ratios
# - Para las features del modelo, NO incluyas `margen_neto` ni `ROA` (contienen la variable objetivo). Usa solo `endeudamiento` más las columnas originales que consideres relevantes (ej: `activos_musd`, `ingresos_musd`, `costos_musd`)
# - Muestra las estadísticas descriptivas de los ratios creados

# %%
# Ejercicio 2: Calcular ratios financieros
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Regresión Logística
#
# Entrena un modelo de Regresión Logística:
#
# 1. Define las features `X` (usa: `endeudamiento`, `activos_musd`, `ingresos_musd`, `costos_musd`) y el target `y` = `rentable`
# 2. Divide en train/test (80/20, random_state=42)
# 3. Entrena `LogisticRegression(max_iter=1000, random_state=42)`
# 4. Genera predicciones sobre test
# 5. Muestra la **matriz de confusión** como heatmap
# 6. Imprime el `classification_report` con target_names=['No rentable', 'Rentable']

# %%
# Ejercicio 3: Regresión Logística
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: Árbol de Decisión
#
# Entrena un Árbol de Decisión con los mismos datos:
#
# 1. Crea un `DecisionTreeClassifier(max_depth=3, random_state=42)`
# 2. Entrena con los datos de train
# 3. Genera predicciones sobre test
# 4. Visualiza el árbol con `plot_tree()` (usa `feature_names` y `class_names=['No rentable', 'Rentable']`)
# 5. Imprime la accuracy del modelo

# %%
# Ejercicio 4: Árbol de Decisión
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Random Forest
#
# Entrena un Random Forest con los mismos datos:
#
# 1. Crea un `RandomForestClassifier(n_estimators=100, random_state=42)`
# 2. Entrena con los datos de train
# 3. Genera predicciones sobre test
# 4. Imprime la accuracy
# 5. Crea una tabla comparativa de accuracy de los 3 modelos:
#
# | Modelo | Accuracy |
# |--------|----------|
# | Regresión Logística | ??? |
# | Árbol de Decisión | ??? |
# | Random Forest | ??? |

# %%
# Ejercicio 5: Random Forest
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Selección del mejor modelo
#
# Analiza los resultados y responde:
#
# 1. ¿Cuál de los 3 modelos tiene la mejor accuracy en el conjunto de test?
# 2. Obtén la importancia de variables del Random Forest (`feature_importances_`) y crea un gráfico de barras horizontal
# 3. ¿Cuál es la feature más importante según el Random Forest?
# 4. ¿Tiene sentido financiero que esa variable sea la más importante? Justifica.
# 5. Si fueras analista de crédito, ¿cuál modelo elegirías y por qué? (Considera no solo accuracy sino también interpretabilidad)

# %%
# Ejercicio 6: Selección del mejor modelo
# Tu código aquí

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste:
#
# | Paso | Qué hiciste |
# |------|-------------|
# | 1. Variable objetivo | Creaste una variable binaria (rentable/no rentable) |
# | 2. Feature engineering | Calculaste ratios financieros como variables predictoras |
# | 3. Modelo 1 | Regresión Logística con matriz de confusión |
# | 4. Modelo 2 | Árbol de Decisión visualizado |
# | 5. Modelo 3 | Random Forest con importancia de variables |
# | 6. Comparación | Selección del mejor modelo con justificación |
#
# ## 📚 Referencias
#
# 1. Scikit-learn developers. (2024). *Supervised learning*. https://scikit-learn.org/stable/supervised_learning.html
#
# 2. Ross, S. A., Westerfield, R. W., & Jordan, B. D. (2019). *Fundamentals of Corporate Finance* (12th ed.). McGraw-Hill.
