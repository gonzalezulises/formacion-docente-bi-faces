# %% [markdown]
# # 🧪 Laboratorio 4: Visualizaciones con Datos Económicos
#
# **Módulo 2** | **Laboratorio 4** | **Duración estimada: 1h**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-02-analisis-visualizacion/laboratorios/lab_04_visualizacion_ejercicios.ipynb)
#
# ---
#
# En este laboratorio crearás **visualizaciones profesionales** utilizando datos económicos de Venezuela y América Latina. Trabajarás con indicadores del BCV (Banco Central de Venezuela) y datos de inflación comparativa de la región.

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Nivel | Indicador de logro |
# |---|-----------|-------|--------------------||
# | 1 | Crear gráficos de línea con series temporales | Procedimental | Grafica indicadores económicos en el tiempo |
# | 2 | Comparar países con gráficos multi-línea | Procedimental | Superpone series de múltiples países |
# | 3 | Usar scatter plots para relaciones económicas | Procedimental | Visualiza relaciones entre PIB, desempleo e inflación |
# | 4 | Crear figuras compuestas de calidad | Aplicado | Produce dashboards con múltiples paneles |
# | 5 | Personalizar figuras para presentaciones | Aplicado | Genera gráficos con calidad de publicación |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# Como docente de Economía, Administración o Contaduría en FACES, frecuentemente necesitas:
#
# - Presentar indicadores macroeconómicos en tus clases
# - Comparar la situación de Venezuela con otros países de la región
# - Crear figuras para artículos de investigación o informes institucionales
# - Analizar tendencias históricas de variables económicas

# %% [markdown]
# ---
#
# ## ⚙️ Configuración inicial

# %%
# ============================================================
# Configuración inicial (ejecuta esta celda sin modificar)
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12
sns.set_palette('Set2')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# Cargar datasets
df_bcv = pd.read_csv('../../datasets/economia/indicadores_bcv.csv')
df_latam = pd.read_csv('../../datasets/economia/inflacion_latam.csv')

# Convertir fecha a datetime en indicadores BCV
df_bcv['fecha'] = pd.to_datetime(df_bcv['fecha'])

print('✅ Bibliotecas y datasets cargados')
print(f'\n📊 indicadores_bcv: {df_bcv.shape}')
print(f'   Columnas: {list(df_bcv.columns)}')
print(f'   Rango temporal: {df_bcv["fecha"].min().strftime("%Y-%m")} a {df_bcv["fecha"].max().strftime("%Y-%m")}')
print(f'\n📊 inflacion_latam: {df_latam.shape}')
print(f'   Columnas: {list(df_latam.columns)}')
print(f'   Países: {df_latam["pais"].unique().tolist()}')
print(f'   Años: {df_latam["anio"].min()} a {df_latam["anio"].max()}')

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Gráfico de línea — Inflación mensual de Venezuela
#
# Usando el dataset `indicadores_bcv.csv` (ya cargado como `df_bcv`):
#
# 1. Crea un gráfico de línea de `inflacion_mensual` vs `fecha`
# 2. Añade título: "Inflación Mensual de Venezuela (BCV)"
# 3. Etiqueta los ejes: "Fecha" e "Inflación mensual (%)"
# 4. Añade una grilla suave
#
# **Pista:** La columna `fecha` ya está convertida a datetime.

# %%
# ============================================================
# Ejercicio 1: Línea de inflación mensual
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: Multi-línea — Comparar inflación por país
#
# Usando `inflacion_latam.csv` (ya cargado como `df_latam`):
#
# 1. Selecciona 3 países para comparar: **Venezuela, Colombia y Argentina**
# 2. Crea un gráfico con **3 líneas** (una por país)
# 3. Usa colores distintos para cada país
# 4. Añade leyenda, título y etiquetas de ejes
#
# **Pista:** Filtra con `df_latam[df_latam['pais'] == 'Venezuela']` para cada país, luego grafica en el mismo eje.

# %%
# ============================================================
# Ejercicio 2: Comparación de inflación por país
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Gráfico de barras — Top 5 países con mayor inflación promedio
#
# 1. Calcula la inflación anual promedio por país (a lo largo de todos los años)
# 2. Ordena de mayor a menor y selecciona los **top 5**
# 3. Crea un gráfico de **barras horizontales**
# 4. Añade los valores numéricos al final de cada barra
#
# **Pista:** Usa `df_latam.groupby('pais')['inflacion_anual'].mean().sort_values(ascending=False).head(5)`

# %%
# ============================================================
# Ejercicio 3: Top 5 inflación promedio
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: Scatter plot — PIB per cápita vs desempleo
#
# 1. Crea un scatter plot de `pib_per_capita_usd` (eje X) vs `desempleo_pct` (eje Y)
# 2. Colorea los puntos por `pais`
# 3. Añade título: "Relación entre PIB per cápita y Desempleo en América Latina"
# 4. Añade leyenda
#
# **Pista:** Puedes usar `sns.scatterplot(data=df_latam, x='pib_per_capita_usd', y='desempleo_pct', hue='pais')`

# %%
# ============================================================
# Ejercicio 4: Scatter PIB vs desempleo
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Boxplot — Distribución de inflación por país
#
# 1. Crea un boxplot de `inflacion_anual` agrupado por `pais`
# 2. Ordena los países por su mediana de inflación (de mayor a menor)
# 3. Rota las etiquetas del eje X para que sean legibles
# 4. **Interpreta:** ¿Qué país tiene mayor variabilidad en su inflación?
#
# **Pista:** Para ordenar, calcula el orden con `df_latam.groupby('pais')['inflacion_anual'].median().sort_values(ascending=False).index` y usa ese orden en el gráfico.

# %%
# ============================================================
# Ejercicio 5: Boxplot de inflación por país
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Subplots — Panel de indicadores BCV
#
# Crea una figura con **4 paneles** (2x2) usando `indicadores_bcv.csv`, mostrando:
#
# 1. **Panel 1:** `inflacion_mensual` a lo largo del tiempo
# 2. **Panel 2:** `tipo_cambio_indice` a lo largo del tiempo
# 3. **Panel 3:** `liquidez_monetaria_indice` a lo largo del tiempo
# 4. **Panel 4:** `reservas_internacionales_mmusd` a lo largo del tiempo
#
# Cada panel debe tener su propio título y etiqueta del eje Y.
#
# **Nota:** Algunas columnas pueden tener valores faltantes. Usa `.dropna()` si es necesario.

# %%
# ============================================================
# Ejercicio 6: Panel de 4 indicadores BCV
# ============================================================

# fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 7: Figura pulida para presentación
#
# Crea **una sola figura de alta calidad** que puedas usar en una presentación académica. Debe incluir:
#
# - Título claro y descriptivo
# - Ejes etiquetados con unidades
# - Colores profesionales (no los predeterminados)
# - Leyenda si hay múltiples series
# - Anotaciones o etiquetas en puntos clave
# - Nota al pie con la fuente de datos
# - Bordes superiores y derechos eliminados (`ax.spines`)
#
# **Sugerencia:** Podrías hacer una comparación de inflación entre 3-4 países, o un gráfico de la evolución de las reservas internacionales.

# %%
# ============================================================
# Ejercicio 7: Figura pulida para presentación
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 8 (Opcional): Heatmap de inflación por país y año
#
# Crea una **tabla pivote** y visualízala como heatmap:
#
# 1. Usa `df_latam.pivot_table(values='inflacion_anual', index='pais', columns='anio')` para crear la tabla pivote
# 2. Visualízala con `sns.heatmap()` con anotaciones
# 3. Usa una paleta secuencial como `YlOrRd` (amarillo-naranja-rojo)
# 4. **Interpreta:** ¿En qué países y años se concentran las inflaciones más altas?

# %%
# ============================================================
# Ejercicio 8 (Opcional): Heatmap inflación país x año
# ============================================================

# Tu código aquí

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste:
#
# | Tipo de gráfico | Datos utilizados | Aplicación |
# |----------------|-----------------|----------|
# | Línea | Inflación mensual BCV | Serie temporal |
# | Multi-línea | Inflación por país | Comparación internacional |
# | Barras | Inflación promedio | Ranking de países |
# | Scatter | PIB vs desempleo | Relación económica |
# | Boxplot | Inflación por país | Variabilidad comparada |
# | Subplots | Indicadores BCV | Dashboard |
# | Heatmap | Inflación país x año | Patrón espacio-temporal |
#
# ## 📚 Referencias
#
# - Matplotlib Tutorial: [https://matplotlib.org/stable/tutorials/](https://matplotlib.org/stable/tutorials/)
# - Seaborn Gallery: [https://seaborn.pydata.org/examples/](https://seaborn.pydata.org/examples/)
# - BCV Indicadores: [https://www.bcv.org.ve/](https://www.bcv.org.ve/)
#
# ---
#
# *Notebook desarrollado para el programa de Formación Docente en Ciencia de Datos y Business Intelligence — FACES, Universidad Catolica Andres Bello (UCAB).*
