# %% [markdown]
# # 🧪 Laboratorio 3: EDA sobre Rendimiento Académico FACES
#
# **Módulo 2** | **Laboratorio 3** | **Duración estimada: 1h**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-02-analisis-visualizacion/laboratorios/lab_03_eda_ejercicios.ipynb)
#
# ---
#
# En este laboratorio realizarás un **Análisis Exploratorio de Datos (EDA) completo** sobre el dataset de rendimiento académico de FACES. Aplicarás todas las técnicas aprendidas en la sesión teórica: estadísticas descriptivas, distribuciones, valores faltantes, outliers, correlaciones y tablas cruzadas.

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# | # | Competencia | Nivel | Indicador de logro |
# |---|-----------|-------|--------------------||
# | 1 | Realizar un EDA completo sobre datos reales | Aplicado | Ejecuta los 7 pasos del EDA sistemático |
# | 2 | Interpretar estadísticas descriptivas | Aplicado | Traduce números en conclusiones académicas |
# | 3 | Visualizar patrones en datos universitarios | Aplicado | Crea gráficos que revelan patrones ocultos |
# | 4 | Comunicar hallazgos de datos | Aplicado | Escribe conclusiones claras basadas en evidencia |

# %% [markdown]
# ## 💡 ¿Por qué es importante para tu práctica docente?
#
# Este laboratorio simula un escenario real: como docente de FACES, recibes un dataset con datos de rendimiento estudiantil y necesitas **explorarlo para identificar patrones, problemas y oportunidades de mejora**. Las conclusiones que obtengas podrían informar decisiones de política académica, tutoría estudiantil o diseño curricular.

# %% [markdown]
# ---
#
# ## ⚙️ Configuración inicial

# %%
# ============================================================
# Configuración inicial (ejecuta esta celda sin modificar)
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
sns.set_palette('Set2')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

print('✅ Bibliotecas cargadas exitosamente')

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 1: Cargar e inspeccionar los datos
#
# Carga el dataset `rendimiento_academico.csv` y realiza una inspección inicial:
#
# 1. Carga el archivo CSV en un DataFrame llamado `df`
# 2. Muestra las dimensiones del dataset (filas x columnas)
# 3. Muestra los tipos de datos de cada columna con `.dtypes`
# 4. Muestra las primeras 5 filas con `.head()`
# 5. Muestra un resumen estadístico con `.describe()`
#
# **Columnas esperadas:** `estudiante_id, carrera, semestre, genero, edad, promedio, materias_inscritas, materias_aprobadas, materias_reprobadas, asistencia_pct, beca, trabaja`

# %%
# ============================================================
# Ejercicio 1: Cargar e inspeccionar
# ============================================================

# 1. Cargar el dataset
# Tu código aquí

# 2. Dimensiones
# Tu código aquí

# 3. Tipos de datos
# Tu código aquí

# 4. Primeras filas
# Tu código aquí

# 5. Resumen estadístico
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 2: Valores faltantes
#
# Verifica si hay valores faltantes en el dataset:
#
# 1. Usa `.isnull().sum()` para contar faltantes por columna
# 2. Calcula el porcentaje de faltantes por columna
# 3. Si hay faltantes, crea un heatmap con `sns.heatmap(df.isnull())` para visualizar el patrón
# 4. Si **no** hay faltantes, escribe un comentario indicándolo y explica por qué es inusual en datos reales

# %%
# ============================================================
# Ejercicio 2: Valores faltantes
# ============================================================

# 1. Contar faltantes por columna
# Tu código aquí

# 2. Porcentaje de faltantes
# Tu código aquí

# 3. Visualizar (si aplica) o comentar
# Tu código aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 3: Distribución del promedio
#
# Analiza la distribución de la variable `promedio`:
#
# 1. Crea un histograma con curva KDE superpuesta
# 2. Añade líneas verticales para la media y la mediana
# 3. Calcula: media, mediana, desviación estándar, mínimo y máximo
# 4. **Interpreta:** ¿La distribución es simétrica o sesgada? ¿La mayoría de estudiantes está por encima o por debajo de la nota mínima aprobatoria (10 puntos)?

# %%
# ============================================================
# Ejercicio 3: Distribución del promedio
# ============================================================

# 1. Histograma + KDE
# Tu código aquí

# 2. Líneas de media y mediana
# Tu código aquí

# 3. Estadísticas
# Tu código aquí

# 4. Interpretación (escribe un comentario)
# Tu interpretación aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 4: Boxplot del promedio por carrera
#
# Compara el rendimiento académico entre carreras:
#
# 1. Crea un boxplot de `promedio` agrupado por `carrera`
# 2. Añade una línea horizontal con el promedio general
# 3. **Responde:**
#    - ¿Qué carrera tiene mayor variabilidad (caja más ancha)?
#    - ¿Qué carrera tiene la mediana más alta?
#    - ¿Se observan outliers? ¿En qué carreras?

# %%
# ============================================================
# Ejercicio 4: Boxplot por carrera
# ============================================================

# 1. Boxplot
# Tu código aquí

# 2. Línea de promedio general
# Tu código aquí

# 3. Respuestas
# Tu interpretación aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 5: Tabla cruzada — Género x Beca
#
# Investiga si hay diferencias de género en el acceso a becas:
#
# 1. Crea una tabla cruzada (`pd.crosstab`) de `genero` x `beca` con conteos
# 2. Crea otra tabla cruzada con **porcentajes por fila** (`normalize='index'`)
# 3. **Responde:** ¿Hay diferencia en el porcentaje de becados entre hombres y mujeres? ¿Es significativa?

# %%
# ============================================================
# Ejercicio 5: Tabla cruzada género x beca
# ============================================================

# 1. Crosstab con conteos
# Tu código aquí

# 2. Crosstab con porcentajes
# Tu código aquí

# 3. Interpretación
# Tu interpretación aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 6: Heatmap de correlaciones
#
# Analiza las correlaciones entre las variables numéricas:
#
# 1. Calcula la matriz de correlación con `.corr()`
# 2. Crea un heatmap con anotaciones, usando la paleta divergente `RdBu_r`
# 3. Usa una máscara para el triángulo superior (`np.triu`)
# 4. **Responde:** ¿Qué variables tienen la correlación más fuerte con `promedio`? ¿Tiene sentido?

# %%
# ============================================================
# Ejercicio 6: Heatmap de correlaciones
# ============================================================

# 1. Matriz de correlación
# Tu código aquí

# 2. Heatmap
# Tu código aquí

# 3. Interpretación
# Tu interpretación aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 7: Comparación — Estudiantes que trabajan vs no trabajan
#
# Investiga el impacto del trabajo en el rendimiento académico:
#
# 1. Filtra el DataFrame en dos grupos: `trabaja == True` y `trabaja == False`
# 2. Calcula el promedio de `promedio` y `asistencia_pct` para cada grupo
# 3. Crea un gráfico de barras comparando ambos grupos
# 4. **Responde:** ¿Los estudiantes que trabajan tienen menor rendimiento? ¿Cuál es la diferencia en puntos?

# %%
# ============================================================
# Ejercicio 7: Estudiantes que trabajan vs no trabajan
# ============================================================

# 1. Filtrar grupos
# Tu código aquí

# 2. Calcular promedios por grupo
# Tu código aquí

# 3. Gráfico de barras comparativo
# Tu código aquí

# 4. Interpretación
# Tu interpretación aquí

# %% [markdown]
# ---
#
# ## ✏️ Ejercicio 8: Resumen de hallazgos
#
# Escribe un resumen ejecutivo de tu EDA. Identifica y documenta **al menos 3 hallazgos clave** en formato markdown.
#
# Para cada hallazgo, incluye:
# - Una descripción clara del patrón observado
# - El dato específico que lo sustenta
# - Una posible implicación para la gestión académica

# %% [markdown]
# ### Mis hallazgos clave:
#
# **Hallazgo 1:** *(Título)*
#
# - Descripción: ...
# - Dato: ...
# - Implicación: ...
#
# **Hallazgo 2:** *(Título)*
#
# - Descripción: ...
# - Dato: ...
# - Implicación: ...
#
# **Hallazgo 3:** *(Título)*
#
# - Descripción: ...
# - Dato: ...
# - Implicación: ...

# %% [markdown]
# ---
#
# ## 📋 Resumen
#
# En este laboratorio practicaste el flujo completo de un EDA:
#
# ```
# Cargar → Inspeccionar → Faltantes → Distribuciones → Outliers → Correlaciones → Tablas cruzadas → Comparaciones → Conclusiones
# ```
#
# Este mismo flujo puedes aplicarlo a **cualquier dataset** que encuentres en tu trabajo académico.
#
# ## 📚 Referencias
#
# - McKinney, W. (2022). *Python for Data Analysis* (3rd ed.). O'Reilly Media.
# - pandas Documentation: [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/)
# - seaborn Tutorial: [https://seaborn.pydata.org/tutorial.html](https://seaborn.pydata.org/tutorial.html)
#
# ---
#
# *Notebook desarrollado para el programa de Formación Docente en Ciencia de Datos y Business Intelligence — FACES, Universidad de Carabobo.*
