# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-03-business-intelligence/laboratorios/entregable_dashboard_prototipo.ipynb)
#
# # Entregable — Prototipo de dashboard para mi asignatura
#
# **Módulo 3: Business Intelligence aplicado a decisiones**
# **Instructora:** Ilda Rojas
#
# ---
#
# ## Instrucciones
#
# Complete cada sección de este template para diseñar un prototipo de dashboard aplicable a su asignatura, departamento o área de trabajo. Este entregable sintetiza todo lo aprendido en el Módulo 3.
#
# **Formato de entrega:** Este notebook completado + archivo .pbix o enlace a Tableau Public con el prototipo funcional.
#
# **Fecha de entrega:** A definir por la instructora.

# %% [markdown]
# ---
#
# ## 1. Pregunta de decisión
#
# Todo dashboard debe responder una pregunta de decisión concreta. Sin pregunta, no hay dashboard útil.
#
# **¿Qué pregunta de decisión busca responder este dashboard?**
#
# *Ejemplo: "¿Cuáles asignaturas tienen mayor tasa de reprobación y requieren intervención pedagógica?"*
#
# **Su pregunta:**
#
#
#
# **¿Qué acción se tomaría con base en la respuesta?**
#
# *Ejemplo: "Asignar tutores adicionales a las asignaturas con tasa de reprobación > 40%"*
#
# **Su respuesta:**

# %% [markdown]
# ---
#
# ## 2. Audiencia objetivo
#
# **¿Quién usará este dashboard?**
#
# | Pregunta | Su respuesta |
# |---|---|
# | **Cargo/rol** | (ej: Coordinador de carrera, Decano, Docente) |
# | **Nivel técnico** | (ej: Básico, intermedio, avanzado en datos) |
# | **Frecuencia de uso** | (ej: Diario, semanal, mensual, semestral) |
# | **Decisiones que toma** | (ej: Asignación de recursos, evaluación de desempeño) |
# | **Contexto de uso** | (ej: Reunión de consejo, revisión individual, presentación) |

# %% [markdown]
# ---
#
# ## 3. KPIs seleccionados (máximo 5)
#
# Seleccione los KPIs más relevantes para su pregunta de decisión. Recuerde: menos es más.
#
# ### KPI 1 (principal)
#
# | Campo | Su respuesta |
# |---|---|
# | **Nombre** | |
# | **Fórmula** | |
# | **Meta** | |
# | **Semáforo** | Verde: ___ / Amarillo: ___ / Rojo: ___ |
# | **Frecuencia** | |
#
# ### KPI 2
#
# | Campo | Su respuesta |
# |---|---|
# | **Nombre** | |
# | **Fórmula** | |
# | **Meta** | |
# | **Semáforo** | Verde: ___ / Amarillo: ___ / Rojo: ___ |
# | **Frecuencia** | |
#
# ### KPI 3
#
# | Campo | Su respuesta |
# |---|---|
# | **Nombre** | |
# | **Fórmula** | |
# | **Meta** | |
# | **Semáforo** | Verde: ___ / Amarillo: ___ / Rojo: ___ |
# | **Frecuencia** | |
#
# ### KPI 4 (opcional)
#
# | Campo | Su respuesta |
# |---|---|
# | **Nombre** | |
# | **Fórmula** | |
# | **Meta** | |
#
# ### KPI 5 (opcional)
#
# | Campo | Su respuesta |
# |---|---|
# | **Nombre** | |
# | **Fórmula** | |
# | **Meta** | |

# %% [markdown]
# ---
#
# ## 4. Fuentes de datos
#
# **¿De dónde provienen los datos para este dashboard?**
#
# | # | Fuente | Formato | Frecuencia de actualización | Responsable |
# |---|---|---|---|---|
# | 1 | | (CSV, Excel, BD, API) | (diaria, semanal, etc.) | |
# | 2 | | | | |
# | 3 | | | | |
#
# **¿Los datos están disponibles actualmente?**
#
# - [ ] Sí, tengo acceso a los datos
# - [ ] Parcialmente, necesito solicitar acceso a: ____________
# - [ ] No, necesito recopilarlos. Plan: ____________
#
# **¿Se requiere transformación de datos?**
#
# Describa brevemente qué limpieza o transformación necesitan los datos:

# %% [markdown]
# ---
#
# ## 5. Boceto del layout
#
# Diseñe el layout de su dashboard. Puede:
# - Completar el esquema a continuación
# - Dibujar en papel y adjuntar foto
# - Crear directamente en Power BI / Tableau
#
# ### Esquema del dashboard
#
# ```
# ┌────────────────────────────────────────────────────────────┐
# │                                                            │
# │  Título: ________________________________________________  │
# │  Subtítulo: _____________________________________________  │
# │                                                            │
# ├────────────┬────────────┬────────────┬────────────────────┤
# │            │            │            │                    │
# │  KPI 1:    │  KPI 2:    │  KPI 3:    │  Filtro(s):       │
# │  ________  │  ________  │  ________  │  ______________   │
# │            │            │            │                    │
# ├────────────┴────────────┴────────────┼────────────────────┤
# │                                      │                    │
# │  Visualización 1:                    │  Visualización 2:  │
# │  Tipo: _______________               │  Tipo: __________  │
# │  Variable X: _________               │  Variable X: _____ │
# │  Variable Y: _________               │  Variable Y: _____ │
# │  Título: _____________               │  Título: ________  │
# │                                      │                    │
# ├──────────────────────────────────────┼────────────────────┤
# │                                      │                    │
# │  Visualización 3 (si aplica):        │  Notas / contexto: │
# │  Tipo: _______________               │  ________________  │
# │                                      │  ________________  │
# │                                      │                    │
# └──────────────────────────────────────┴────────────────────┘
# ```
#
# ### Justificación de diseño
#
# **¿Por qué eligió estos tipos de gráficos?**
#
# | Visualización | Tipo elegido | Justificación |
# |---|---|---|
# | Vis. 1 | | |
# | Vis. 2 | | |
# | Vis. 3 | | |
#
# **Paleta de colores:**
#
# | Elemento | Color | Código hex |
# |---|---|---|
# | Primario | | |
# | Secundario | | |
# | Alerta / atención | | |
# | Fondo | | |

# %% [markdown]
# ---
#
# ## 6. Explicación de uso en el curso
#
# Describa cómo usaría este dashboard en su práctica docente o de gestión.
#
# ### ¿Cómo lo usaría en su asignatura o departamento?
#
# *Describa un escenario concreto de uso:*
#
#
#
# ### ¿Con qué frecuencia lo consultaría?
#
# - [ ] Al inicio de cada semestre (planificación)
# - [ ] Mensualmente (seguimiento)
# - [ ] Al final del semestre (evaluación)
# - [ ] Antes de reuniones de consejo/comité
# - [ ] Otro: ____________
#
# ### ¿Qué decisiones tomaría con base en este dashboard?
#
# | Escenario del dashboard | Decisión / Acción |
# |---|---|
# | Si KPI 1 está en rojo | |
# | Si KPI 2 muestra tendencia negativa | |
# | Si se identifica un outlier | |

# %% [markdown]
# ---
#
# ## Criterios de evaluación
#
# | Criterio | Peso | Descripción |
# |---|---|---|
# | Pregunta de decisión | 15% | Clara, específica y relevante para FACES |
# | KPIs | 20% | Bien definidos, con fórmula, meta y semáforo |
# | Fuentes de datos | 10% | Identificadas y factibles |
# | Layout y diseño | 25% | Aplica principios de visualización del módulo |
# | Prototipo funcional | 20% | Dashboard construido en Power BI / Tableau |
# | Explicación de uso | 10% | Aplicación práctica clara y realista |
#
# ---
#
# **Nota:** Este entregable es individual. El prototipo funcional puede usar los datos del curso (`rendimiento_academico.csv`) o datos propios de su área.
