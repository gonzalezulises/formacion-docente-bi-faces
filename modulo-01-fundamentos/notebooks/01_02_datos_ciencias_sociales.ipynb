# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gonzalezulises/formacion-docente-bi-faces/blob/main/modulo-01-fundamentos/notebooks/01_02_datos_ciencias_sociales.ipynb)
#
# # 01.02 — Datos en ciencias sociales
#
# **Módulo 1: Pensar con datos en ciencias sociales y economía**
# **Duración:** 1 hora
# **Facilitador:** Ulises González
#
# ---
#
# ## Objetivos de aprendizaje
#
# - Distinguir entre datos estructurados y no estructurados
# - Clasificar variables según su naturaleza y nivel de medición
# - Comprender las implicaciones del nivel de medición para el análisis

# %% [markdown]
# ## 1. Fuentes de datos en ciencias sociales
#
# A diferencia de las ciencias naturales, donde los datos provienen de instrumentos de medición controlados, en ciencias sociales las fuentes son diversas y cada una tiene sus particularidades.
#
# ### 1.1 Datos estructurados
#
# Organizados en filas y columnas, con formato predecible:
#
# - **Encuestas y cuestionarios**: la fuente más clásica en ciencias sociales. Escalas Likert, preguntas cerradas, datos demográficos.
# - **Registros administrativos**: matrícula universitaria, nóminas, declaraciones fiscales, registros del IVSS.
# - **Bases de datos públicas**: Banco Mundial, CEPAL, INE, BCV — series históricas de indicadores.
# - **Datos transaccionales**: ventas, movimientos bancarios, registros contables.
#
# ### 1.2 Datos no estructurados
#
# Sin formato tabular predefinido, requieren procesamiento previo:
#
# - **Entrevistas y grupos focales**: transcripciones de texto que requieren codificación.
# - **Redes sociales**: publicaciones, comentarios, reacciones — texto libre con metadatos.
# - **Documentos institucionales**: actas, informes, normativas — texto con estructura variable.
# - **Medios de comunicación**: artículos de prensa, discursos — para análisis de contenido.
#
# ### 1.3 Datos mixtos
#
# La realidad de la investigación social suele combinar ambos:
#
# | Proyecto | Datos estructurados | Datos no estructurados |
# |----------|--------------------|-----------------------|
# | Estudio de clima laboral | Encuesta con escala Likert | Entrevistas a profundidad |
# | Análisis de política fiscal | Series del BCV | Discursos del ministro |
# | Evaluación docente | Calificaciones numéricas | Comentarios abiertos de estudiantes |

# %% [markdown]
# ## 2. Tipos de variables
#
# ### 2.1 Variables cualitativas (categóricas)
#
# Representan categorías o grupos, no cantidades.
#
# #### Nominales
# - No tienen orden inherente
# - Ejemplos: carrera (Economía, Administración, Contaduría, RRII), estado civil, género, sector económico
# - Operaciones válidas: frecuencia, moda, chi-cuadrado
#
# #### Ordinales
# - Tienen un orden natural pero las distancias entre categorías no son iguales
# - Ejemplos: nivel educativo (primaria < secundaria < universitario), escala Likert (muy insatisfecho → muy satisfecho), nivel de riesgo (bajo, medio, alto)
# - Operaciones válidas: mediana, percentiles, correlación de Spearman
#
# ### 2.2 Variables cuantitativas (numéricas)
#
# Representan cantidades medibles.
#
# #### De intervalo
# - Distancias iguales entre valores pero **sin cero absoluto**
# - Ejemplos: temperatura en °C, puntuación en un test estandarizado, año calendario
# - Operaciones válidas: media, desviación estándar, correlación de Pearson
# - **No se puede decir** "el doble" (20°C no es el doble de calor que 10°C)
#
# #### De razón
# - Distancias iguales **con cero absoluto**
# - Ejemplos: salario, edad, matrícula estudiantil, PIB, tasa de desempleo
# - Operaciones válidas: todas las anteriores + proporciones y tasas
# - **Sí se puede decir** "el doble" (un salario de $2000 es el doble de $1000)

# %% [markdown]
# ## 3. Niveles de medición y sus implicaciones
#
# El nivel de medición de una variable **determina qué análisis son válidos**. Usar una técnica inadecuada produce resultados sin sentido.
#
# | Nivel | Ejemplo | Media | Mediana | Moda | Comparar proporciones | Regresión |
# |-------|---------|:-----:|:-------:|:----:|:--------------------:|:---------:|
# | Nominal | Carrera | ❌ | ❌ | ✅ | ✅ | Solo como dummy |
# | Ordinal | Satisfacción | ⚠️ | ✅ | ✅ | ✅ | Con precaución |
# | Intervalo | Puntaje test | ✅ | ✅ | ✅ | ✅ | ✅ |
# | Razón | Salario | ✅ | ✅ | ✅ | ✅ | ✅ |
#
# ### El debate de las escalas Likert
#
# ¿Es ordinal o de intervalo? Este es uno de los debates más frecuentes en ciencias sociales:
#
# - **Postura conservadora**: es ordinal, la distancia entre "de acuerdo" y "muy de acuerdo" no es igual a la distancia entre "neutral" e "indiferente".
# - **Postura pragmática**: con 5+ puntos y distribución razonable, se puede tratar como intervalo para efectos prácticos.
# - **Recomendación**: reportar ambos análisis (paramétricos y no paramétricos) cuando sea posible.

# %% [markdown]
# ## 4. Ejemplo práctico: un dataset de FACES
#
# Consideremos una tabla de datos de la encuesta semestral a estudiantes:
#
# | Variable | Ejemplo de valor | Tipo | Nivel |
# |----------|-----------------|------|-------|
# | Cédula | V-26.xxx.xxx | Cualitativa | Nominal (identificador) |
# | Carrera | Economía | Cualitativa | Nominal |
# | Semestre | 6to | Cualitativa | Ordinal |
# | Satisfacción general | 4 (de 5) | Cualitativa | Ordinal |
# | Promedio acumulado | 15.7 | Cuantitativa | De intervalo |
# | Horas de estudio/semana | 22 | Cuantitativa | De razón |
# | Ingreso familiar mensual | $450 | Cuantitativa | De razón |
# | Comentarios abiertos | "Los horarios..." | No estructurado | N/A |

# %%
# Ejemplo: representación de un mini-dataset de estudiantes de FACES
# (No necesitas ejecutar esto — es para ilustrar la estructura)

datos_ejemplo = {
    "carrera": ["Economía", "Administración", "Contaduría", "RRII", "Economía"],
    "semestre": [6, 4, 8, 2, 6],
    "satisfaccion": [4, 3, 5, 2, 4],
    "promedio": [15.7, 13.2, 17.1, 11.8, 14.5],
    "horas_estudio_semana": [22, 15, 30, 8, 18],
    "ingreso_familiar_usd": [450, 320, 580, 200, 400]
}

# Pregunta: ¿Cuáles de estas variables puedo promediar con sentido?
# Respuesta: promedio, horas_estudio_semana, ingreso_familiar_usd
# ¿Y satisfacción? Depende de tu postura (ver debate Likert arriba)

# %% [markdown]
# ## 5. Ejercicio: Clasifica las variables
#
# ### Instrucciones
#
# Para cada variable del siguiente estudio hipotético, indica su **tipo** (cualitativa/cuantitativa) y su **nivel de medición** (nominal, ordinal, intervalo, razón).
#
# **Estudio: "Factores asociados al rendimiento académico en FACES"**
#
# | # | Variable | Tipo | Nivel de medición |
# |---|----------|------|-------------------|
# | 1 | Género del estudiante | *Escribe aquí* | *Escribe aquí* |
# | 2 | Nota final de la asignatura (0-20) | *Escribe aquí* | *Escribe aquí* |
# | 3 | Nivel socioeconómico (A, B, C, D, E) | *Escribe aquí* | *Escribe aquí* |
# | 4 | Número de materias inscritas | *Escribe aquí* | *Escribe aquí* |
# | 5 | Tipo de institución de bachillerato (pública/privada) | *Escribe aquí* | *Escribe aquí* |
# | 6 | Horas dedicadas a trabajo remunerado | *Escribe aquí* | *Escribe aquí* |
# | 7 | Percepción de dificultad (1=muy fácil, 5=muy difícil) | *Escribe aquí* | *Escribe aquí* |
# | 8 | Monto de beca recibida (Bs.) | *Escribe aquí* | *Escribe aquí* |

# %%
# Ejercicio interactivo: Clasifica variables con código
# Ejecuta esta celda y responde las preguntas

import pandas as pd

# Dataset de la encuesta semestral de FACES
encuesta = pd.DataFrame({
    'cedula': ['V-26001', 'V-26002', 'V-26003', 'V-26004', 'V-26005', 'V-26006'],
    'carrera': ['Economía', 'Administración', 'Contaduría', 'RRII', 'Economía', 'Contaduría'],
    'semestre': [6, 4, 8, 2, 6, 3],
    'satisfaccion': [4, 3, 5, 2, 4, 3],
    'promedio': [15.7, 13.2, 17.1, 11.8, 14.5, 12.9],
    'horas_estudio': [22, 15, 30, 8, 18, 12],
    'ingreso_familiar_usd': [450, 320, 580, 200, 400, 280],
    'tipo_bachillerato': ['Privado', 'Público', 'Privado', 'Público', 'Público', 'Privado']
})

print("=== Vista del dataset ===")
print(encuesta.head())
print("\n=== Tipos de datos que Python asigna ===")
print(encuesta.dtypes)
print("\n=== Estadísticas descriptivas ===")
print(encuesta.describe())

# PREGUNTAS para reflexionar:
# 1. Python dice que 'semestre' es int64 (numérico). ¿Es realmente cuantitativo o es ordinal?
# 2. Python dice que 'satisfaccion' es int64. ¿Deberías calcular el promedio de satisfacción?
# 3. ¿Por qué 'cedula' no aparece en describe()? ¿Qué tipo de variable es?
# 4. ¿Qué pasa si calculas encuesta['tipo_bachillerato'].mean()? ¿Por qué?

# %% [markdown]
# ## 5b. Ejercicio avanzado: Casos ambiguos
#
# Algunas variables cambian de nivel según el contexto. Clasifica cada caso Y justifica:
#
# | # | Variable | Contexto A | Contexto B | ¿Cambia el nivel? |
# |---|----------|-----------|-----------|-------------------|
# | 1 | **Edad** | Años cumplidos (25, 32, 41) | Grupo etario (joven/adulto/mayor) | *Escribe: ¿razón u ordinal?* |
# | 2 | **Ingreso** | Monto en USD ($320, $580) | Quintil (Q1, Q2, Q3, Q4, Q5) | *Escribe: ¿razón u ordinal?* |
# | 3 | **Calificación** | Nota numérica (14.5/20) | Aprobado/Reprobado | *Escribe: ¿intervalo o nominal?* |
# | 4 | **Código postal** | 1010, 1060, 1080 | Zona: Este/Oeste/Centro | *Escribe: ¿nominal en ambos?* |
# | 5 | **Año de graduación** | 2018, 2020, 2023 | Antes/Después de pandemia | *Escribe: ¿intervalo u ordinal?* |
#
# **Clave:** El mismo dato puede ser tratado a distintos niveles dependiendo de la pregunta de investigación. Un buen analista elige conscientemente.

# %% [markdown]
# ## 5c. Respuestas sugeridas al ejercicio de clasificación
#
# | # | Variable | Tipo | Nivel | Justificación |
# |---|----------|------|-------|---------------|
# | 1 | Género del estudiante | Cualitativa | Nominal | Categorías sin orden inherente |
# | 2 | Nota final (0-20) | Cuantitativa | De intervalo | Distancias iguales, pero el 0 no significa "ausencia de conocimiento" |
# | 3 | Nivel socioeconómico (A-E) | Cualitativa | Ordinal | Tiene orden (A>B>C>D>E) pero distancias desiguales |
# | 4 | Número de materias inscritas | Cuantitativa | De razón | 0 materias es un cero absoluto, se puede decir "el doble" |
# | 5 | Tipo de institución (pública/privada) | Cualitativa | Nominal | Dos categorías sin orden |
# | 6 | Horas de trabajo remunerado | Cuantitativa | De razón | 0 horas es cero absoluto |
# | 7 | Percepción de dificultad (1-5) | Cualitativa | Ordinal | Escala Likert — debate ordinal vs. intervalo (ver sección 3) |
# | 8 | Monto de beca (Bs.) | Cuantitativa | De razón | 0 Bs. = no tiene beca (cero absoluto) |
#
# **Nota:** La variable 2 (nota final) es debatible. Algunos la tratan como de razón argumentando que 0 = ausencia de respuestas correctas. La clasificación depende del uso que le des.

# %% [markdown]
# ## 6. Reflexión de cierre
#
# - **No todos los números son cuantitativos**: un código postal o un número de cédula son categóricos disfrazados de números.
# - **El nivel de medición no es inherente al dato, sino al uso**: la edad puede ser de razón (años cumplidos) o convertirse en ordinal (joven/adulto/adulto mayor).
# - **Antes de analizar, clasificar**: el primer paso de cualquier proyecto de datos es entender qué tipo de variables tenemos y qué operaciones son válidas.
#
# ---
#
# *Anterior: [01.01 — El ciclo de valor de los datos](01_01_ciclo_valor_datos.ipynb)*
# *Siguiente: [01.03 — Sesgos y falacias](01_03_sesgos_falacias.ipynb)*
